# %% [markdown]
# # JSON_Data Exercise -- Larry Larkin

# %% [markdown]
# ### Load JSON file into Python list

# %%
import pandas as pd
import json

# %%
filepath = "Datasets/MC_Traffic_Violations.json"

# %%
#data is individual JSON objects not separated by commas
#will load data as JSON and put in bigger list to be able to extract values from keys

data = []

# Load all at once
with open(filepath) as file:
    data=(json.load(file))

# %%
#verify that this is a list type
type(data)
# Out:
# dict

# %%
#check number of items in data list
#this is the total number of dictionaries in dataset
len(data)
# Out:
# 2

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
#Determine type of structure for 'data' key
type(data['data'])
# Out:
# list

# %% [markdown]
# #### Verify values within the data structure

# %%
# Display data structure and contents
data['data']
# Out:
# [['row-uhkc.zzjq-4wcp',
#   '00000000-0000-0000-1251-6984DA5C0058',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'e13d2082-55a7-4a93-8836-173be19d2648',
#   '2019-06-01T00:00:00',
#   '13:38:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVER CHANGING LANES WHEN UNSAFE',
#   'RANDOLPH RD / NEW HAMPSHIRE',
#   '39.07592',
#   '-77.0011316666667',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2014',
#   'HYUN',
#   'TK',
#   'SILVER',
#   'Warning',
#   '21-309(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.07592',
#    '-77.0011316666667',
#    None,
#    False],
#   '5',
#   '5',
#   '26',
#   '12',
#   '1'],
#  ['row-2gyt_x7qf-2wbv',
#   '00000000-0000-0000-998A-26215756EF18',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'e13d2082-55a7-4a93-8836-173be19d2648',
#   '2019-06-01T00:00:00',
#   '13:38:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVER FAILURE TO YIELD RIGHT-OF-WAY TO VEH. UPON EMERGING FROM DRIVEWAY',
#   'RANDOLPH RD / NEW HAMPSHIRE',
#   '39.07592',
#   '-77.0011316666667',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2014',
#   'HYUN',
#   'TK',
#   'SILVER',
#   'Warning',
#   '21-705(c)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.07592',
#    '-77.0011316666667',
#    None,
#    False],
#   '5',
#   '5',
#   '26',
#   '12',
#   '1'],
#  ['row-vw3j.9j8a.j364',
#   '00000000-0000-0000-9D56-57613F53F2C7',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'e13d2082-55a7-4a93-8836-173be19d2648',
#   '2019-06-01T00:00:00',
#   '13:38:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO AVOID COLLISION',
#   'RANDOLPH RD / NEW HAMPSHIRE',
#   '39.07592',
#   '-77.0011316666667',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2014',
#   'HYUN',
#   'TK',
#   'SILVER',
#   'Warning',
#   '21-801(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.07592',
#    '-77.0011316666667',
#    None,
#    False],
#   '5',
#   '5',
#   '26',
#   '12',
#   '1'],
#  ['row-y6rs_ymjz.i29c',
#   '00000000-0000-0000-6227-B5AC60516F17',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'a5e9b1eb-f16f-4b01-8530-2a5a921051ba',
#   '2019-06-01T00:00:00',
#   '13:23:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#   'COLUMBIA PIKE / OAK LEAF DR',
#   '39.0407683333333',
#   '-76.9959166666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2008',
#   'MAZDA',
#   '4D',
#   'BLUE, LIGHT',
#   'Citation',
#   '13-401(h)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'ELLICOTT CITY',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0407683333333',
#    '-76.9959166666667',
#    None,
#    False],
#   '5',
#   '5',
#   '18',
#   '21',
#   '1'],
#  ['row-skx8_vuky_cdue',
#   '00000000-0000-0000-3FD4-E248198BD961',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '99bc7c5f-b630-448c-a7e5-98b37efd0902',
#   '2019-06-01T00:00:00',
#   '13:23:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#   'RIVER RD/BRAEBRN PKWY',
#   '38.978335',
#   '-77.13062',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2014',
#   'HOND',
#   '4D',
#   'BRONZE',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'F',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'E - Marked Stationary Radar',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.978335',
#    '-77.13062',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-pvr2-mwi9_usz6',
#   '00000000-0000-0000-B337-A4A8CFE4C7A7',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'a5e9b1eb-f16f-4b01-8530-2a5a921051ba',
#   '2019-06-01T00:00:00',
#   '13:23:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103',
#   'COLUMBIA PIKE / OAK LEAF DR',
#   '39.0407683333333',
#   '-76.9959166666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2008',
#   'MAZDA',
#   '4D',
#   'BLUE, LIGHT',
#   'Citation',
#   '16-303(h)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'ELLICOTT CITY',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0407683333333',
#    '-76.9959166666667',
#    None,
#    False],
#   '5',
#   '5',
#   '18',
#   '21',
#   '1'],
#  ['row-vzj8_w8xm~w2s4',
#   '00000000-0000-0000-78A5-C1F21D22D084',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'a5e9b1eb-f16f-4b01-8530-2a5a921051ba',
#   '2019-06-01T00:00:00',
#   '13:23:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE',
#   'COLUMBIA PIKE / OAK LEAF DR',
#   '39.0407683333333',
#   '-76.9959166666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2008',
#   'MAZDA',
#   '4D',
#   'BLUE, LIGHT',
#   'Citation',
#   '16-303(c)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'ELLICOTT CITY',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0407683333333',
#    '-76.9959166666667',
#    None,
#    False],
#   '5',
#   '5',
#   '18',
#   '21',
#   '1'],
#  ['row-w52c~dx4z_8ym6',
#   '00000000-0000-0000-F47F-A043A3D552B5',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'dc338f50-53da-4fc1-aaa8-4bacffb8a649',
#   '2019-06-01T00:00:00',
#   '13:17:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#   'RIVER RD/BRAEBRN PKWY',
#   '38.9783683333333',
#   '-77.1305916666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'HOND',
#   '4S',
#   'BLUE',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'BETHESDA',
#   'MD',
#   'MD',
#   'E - Marked Stationary Radar',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9783683333333',
#    '-77.1305916666667',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-hqmj-tcd4_ztpt',
#   '00000000-0000-0000-E5C3-6C3F4EA306A2',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '1643d5e9-6927-4325-8646-48b889ec6567',
#   '2019-06-01T00:00:00',
#   '13:13:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#   'WOOTTON PARKWAY @ EDMONSTON DR.',
#   '39.072065',
#   '-77.1385716666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2014',
#   'HONDA',
#   'ODYSSEY',
#   'WHITE',
#   'Warning',
#   '21-201(a1)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'POTOMAC',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.072065',
#    '-77.1385716666667',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-p96m_sum7.bag5',
#   '00000000-0000-0000-7505-3095F3ED0FBA',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'fddf7f5d-6dd7-4e0c-9950-1e73b61e9202',
#   '2019-06-01T00:00:00',
#   '13:06:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'STOPPING, PARKING, LEAVING STANDING VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT',
#   '8512 FENTON ST.',
#   '38.9961883333333',
#   '-77.0248416666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'TOYOTA',
#   'COROLLA',
#   'GOLD',
#   'Citation',
#   '21-1001(a)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9961883333333',
#    '-77.0248416666667',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-qwv3_ik4t_85f2',
#   '00000000-0000-0000-713C-1835F61E8AF6',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'c6e4a810-6023-4e23-874a-0762d6bb6dae',
#   '2019-06-01T00:00:00',
#   '13:02:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY',
#   'RIVER RD/WHITTIER BLVD',
#   '38.97848',
#   '-77.1307816666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2006',
#   'VOLV',
#   'SW',
#   'BLACK',
#   'Warning',
#   '21-801(a)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'BETHESDA',
#   'MD',
#   'MD',
#   'E - Marked Stationary Radar',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97848',
#    '-77.1307816666667',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-dykt_7543.ujav',
#   '00000000-0000-0000-028B-97C5667CE3FC',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '25c5effa-19fb-42ea-9d12-b0bb6e2decf5',
#   '2019-06-01T00:00:00',
#   '12:59:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVER FAIL TO STOP AT STEADY RED ARROW SIGNAL',
#   'S/B GEORGIA AVE / CAMERON ST',
#   '38.9975683333333',
#   '-77.029395',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'CA',
#   '02 - Automobile',
#   '2010',
#   'HONDA',
#   'ACCORD',
#   'GRAY',
#   'Warning',
#   '21-202(h2)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9975683333333',
#    '-77.029395',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-ac63-mqgj-qe6k',
#   '00000000-0000-0000-E91F-C1B7C7071BF5',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '25c5effa-19fb-42ea-9d12-b0bb6e2decf5',
#   '2019-06-01T00:00:00',
#   '12:59:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#   'S/B GEORGIA AVE / CAMERON ST',
#   '38.9975683333333',
#   '-77.029395',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'CA',
#   '02 - Automobile',
#   '2010',
#   'HONDA',
#   'ACCORD',
#   'GRAY',
#   'Citation',
#   '13-401(h)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9975683333333',
#    '-77.029395',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-2in4.9tqk-x2q7',
#   '00000000-0000-0000-980A-19981603E541',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '25c5effa-19fb-42ea-9d12-b0bb6e2decf5',
#   '2019-06-01T00:00:00',
#   '12:59:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'FAILURE NOTIFY ADM. ADDRESS CHANGE',
#   'S/B GEORGIA AVE / CAMERON ST',
#   '38.9975683333333',
#   '-77.029395',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'CA',
#   '02 - Automobile',
#   '2010',
#   'HONDA',
#   'ACCORD',
#   'GRAY',
#   'Warning',
#   '16-116(a)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'SILVER SPRING',
#   'MD',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9975683333333',
#    '-77.029395',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-pj26_j36y.d93z',
#   '00000000-0000-0000-CC17-B6B244D1B0D8',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'b6923cff-5306-4ec6-9789-0a59a5314113',
#   '2019-06-01T00:00:00',
#   '12:46:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'UNAUTHORIZED DISPLAY AND USE OF REGISTRATION PLATE',
#   '29/FAIRLAND RD',
#   '39.0633833333333',
#   '-76.96236',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'NISSAN',
#   'ALTIMA',
#   'WHITE',
#   'Warning',
#   '13-703(g)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'NY',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0633833333333',
#    '-76.96236',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-dgpn.m7mj.zkn3',
#   '00000000-0000-0000-8334-34CC590A56A2',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'b6923cff-5306-4ec6-9789-0a59a5314113',
#   '2019-06-01T00:00:00',
#   '12:46:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE',
#   '29/FAIRLAND RD',
#   '39.0633833333333',
#   '-76.96236',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'NISSAN',
#   'ALTIMA',
#   'WHITE',
#   'Warning',
#   '13-411(f)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'NY',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0633833333333',
#    '-76.96236',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-vrst.zui7_rhy2',
#   '00000000-0000-0000-2889-9F7E73A52235',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'b6923cff-5306-4ec6-9789-0a59a5314113',
#   '2019-06-01T00:00:00',
#   '12:46:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS',
#   '29/FAIRLAND RD',
#   '39.0633833333333',
#   '-76.96236',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'NISSAN',
#   'ALTIMA',
#   'WHITE',
#   'Warning',
#   '13-411(d)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'NY',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0633833333333',
#    '-76.96236',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-kt3k~ffji_wy65',
#   '00000000-0000-0000-8342-E68263AB0E6E',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'b6923cff-5306-4ec6-9789-0a59a5314113',
#   '2019-06-01T00:00:00',
#   '12:46:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#   '29/FAIRLAND RD',
#   '39.0633833333333',
#   '-76.96236',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'NISSAN',
#   'ALTIMA',
#   'WHITE',
#   'Warning',
#   '13-409(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'NY',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0633833333333',
#    '-76.96236',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-35sd.b3bt-9r56',
#   '00000000-0000-0000-99FF-74531B7299E2',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '2e629367-056d-4c18-a424-31003c1e8adb',
#   '2019-06-01T00:00:00',
#   '12:28:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING POSTED MAXIMUM SPEED LIMIT: 54 MPH IN A POSTED 35 MPH ZONE',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97841',
#   '-77.1307366666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'DC',
#   '02 - Automobile',
#   '2017',
#   'AUDI',
#   'A4',
#   'BLACK',
#   'Citation',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'WASHINGTON',
#   'DC',
#   'DC',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97841',
#    '-77.1307366666667',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-r8rn-gdz2~c46q',
#   '00000000-0000-0000-736D-7DA19E3EA143',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ea86a88e-e992-477b-91a6-783b2459941f',
#   '2019-06-01T00:00:00',
#   '12:15:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#   'MONTGOMERY VILLAGE AVE / FREDERICK RD',
#   '39.1520565',
#   '-77.2128355',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'ACUR',
#   '4S',
#   'GRAY',
#   'Warning',
#   '13-401(h)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1520565',
#    '-77.2128355',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '35',
#   '21'],
#  ['row-dvvg_zhmy-ndgm',
#   '00000000-0000-0000-13A0-6D3F823C5A14',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ea86a88e-e992-477b-91a6-783b2459941f',
#   '2019-06-01T00:00:00',
#   '12:15:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103',
#   'MONTGOMERY VILLAGE AVE / FREDERICK RD',
#   '39.1520565',
#   '-77.2128355',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'ACUR',
#   '4S',
#   'GRAY',
#   'Citation',
#   '16-303(h)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1520565',
#    '-77.2128355',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '35',
#   '21'],
#  ['row-icfp~ct3c_p78u',
#   '00000000-0000-0000-F23B-8D877227E00F',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ea86a88e-e992-477b-91a6-783b2459941f',
#   '2019-06-01T00:00:00',
#   '12:15:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'DRIVING TO DRIVE MOTOR VEHICLE ON HIGHWAY WITHOUT REQUIRED LICENSE AND AUTHORIZATION',
#   'MONTGOMERY VILLAGE AVE / FREDERICK RD',
#   '39.1520565',
#   '-77.2128355',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'ACUR',
#   '4S',
#   'GRAY',
#   'Citation',
#   '16-101(a1)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1520565',
#    '-77.2128355',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '35',
#   '21'],
#  ['row-edce_6t4q~b5nw',
#   '00000000-0000-0000-C146-5C43798D1673',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ea86a88e-e992-477b-91a6-783b2459941f',
#   '2019-06-01T00:00:00',
#   '12:15:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'DRIVER CHANGING LANES WHEN UNSAFE',
#   'MONTGOMERY VILLAGE AVE / FREDERICK RD',
#   '39.1520565',
#   '-77.2128355',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'ACUR',
#   '4S',
#   'GRAY',
#   'Citation',
#   '21-309(b)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1520565',
#    '-77.2128355',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '35',
#   '21'],
#  ['row-6gxu_e3ni~kw4e',
#   '00000000-0000-0000-4E33-2A2344465515',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ea86a88e-e992-477b-91a6-783b2459941f',
#   '2019-06-01T00:00:00',
#   '12:15:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE',
#   'MONTGOMERY VILLAGE AVE / FREDERICK RD',
#   '39.1520565',
#   '-77.2128355',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'ACUR',
#   '4S',
#   'GRAY',
#   'Citation',
#   '16-303(c)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1520565',
#    '-77.2128355',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '35',
#   '21'],
#  ['row-5gu7_s889_i2yg',
#   '00000000-0000-0000-DD71-E41584BD719E',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'c81efbed-5f42-4a71-a103-bbbec04d945e',
#   '2019-06-01T00:00:00',
#   '12:14:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING POSTED MAXIMUM SPEED LIMIT: 50 MPH IN A POSTED 35 MPH ZONE',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97841',
#   '-77.1307366666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2005',
#   'MERCEDEZ',
#   'C230',
#   'BLACK',
#   'Citation',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'BETHESDA',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97841',
#    '-77.1307366666667',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-i9b3~647y_ar75',
#   '00000000-0000-0000-7D8E-B054DFA03446',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '63e13a89-df5a-4f13-918b-0285f54a5cd6',
#   '2019-06-01T00:00:00',
#   '12:02:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97849',
#   '-77.1308283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '1999',
#   'LEXUS',
#   'TK',
#   'TAN',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'POTOMAC',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97849',
#    '-77.1308283333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-vrqs_2w3m-i6g8',
#   '00000000-0000-0000-39D8-BC2BCE433B88',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'd64fa8c7-80ab-4d24-a395-85b6ae2be328',
#   '2019-06-01T00:00:00',
#   '11:52:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97849',
#   '-77.1308283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2015',
#   'SUBARU',
#   'FORRESTER',
#   'BLACK',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97849',
#    '-77.1308283333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-whxh~endc_svc6',
#   '00000000-0000-0000-BAC4-399786E0AF4B',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'abcd2723-6436-4117-987b-4c9bf8c66a1c',
#   '2019-06-01T00:00:00',
#   '11:47:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#   '355 @ TWINBROOK PKWY',
#   '39.0583816666667',
#   '-77.1206866666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2008',
#   'TOYOTA',
#   'SIENNA',
#   'BLUE, LIGHT',
#   'Warning',
#   '13-401(h)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0583816666667',
#    '-77.1206866666667',
#    None,
#    False],
#   '1',
#   '1',
#   '25',
#   '60',
#   '12'],
#  ['row-5b8g~w6zu~zvnx',
#   '00000000-0000-0000-C254-F471ED90BB7A',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '7ac6731c-1979-4433-af12-ded06b56c7cc',
#   '2019-06-01T00:00:00',
#   '11:33:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING POSTED MAXIMUM SPEED LIMIT: 49 MPH IN A POSTED 35 MPH ZONE',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97849',
#   '-77.1308283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'HYUNDAI',
#   'ELANTRA',
#   'SILVER',
#   'Citation',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'DISTRICT HEIGHTS',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97849',
#    '-77.1308283333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-gvc9_evbu.ycuc',
#   '00000000-0000-0000-1C2E-7B7DB533E5E0',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '7ac6731c-1979-4433-af12-ded06b56c7cc',
#   '2019-06-01T00:00:00',
#   '11:33:00',
#   'MCP',
#   '2nd District, Bethesda',
#   "DUPLICATION OF DRIVER'S LICENSE",
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97849',
#   '-77.1308283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'HYUNDAI',
#   'ELANTRA',
#   'SILVER',
#   'Warning',
#   '16-302',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'DISTRICT HEIGHTS',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97849',
#    '-77.1308283333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-sazg_mh9f.eppv',
#   '00000000-0000-0000-BCF8-29A286358F42',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '913513d8-1d49-428f-b3a7-f9fe6c01418b',
#   '2019-06-01T00:00:00',
#   '11:24:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#   'RIVER RD / BRAEBURN PKWY',
#   '38.97849',
#   '-77.1308283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2008',
#   'INFINITI',
#   'EX35',
#   'WHITE',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'BETHESDA',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.97849',
#    '-77.1308283333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-izmf~n2w6.rn5a',
#   '00000000-0000-0000-F3B4-762F5A92F258',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'd8064578-ffc1-4e8a-81e0-39b48d8ce244',
#   '2019-06-01T00:00:00',
#   '11:19:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVE ACROSS PRIVATE PROPERTY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#   'SLIGO AVE / FENTON ST',
#   '38.9909283333333',
#   '-77.0242066666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2016',
#   'FIAT',
#   '500',
#   'RED',
#   'Warning',
#   '21-201(a2)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'STEVENSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9909283333333',
#    '-77.0242066666667',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-j8v4~cwvs.iuzj',
#   '00000000-0000-0000-2DCB-C5CAFD0DE7D6',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'd8064578-ffc1-4e8a-81e0-39b48d8ce244',
#   '2019-06-01T00:00:00',
#   '11:19:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#   'SLIGO AVE / FENTON ST',
#   '38.9909283333333',
#   '-77.0242066666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2016',
#   'FIAT',
#   '500',
#   'RED',
#   'Warning',
#   '13-409(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'STEVENSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9909283333333',
#    '-77.0242066666667',
#    None,
#    False],
#   '5',
#   '5',
#   '7',
#   '3065',
#   '1'],
#  ['row-xfmn~pm2s_bmdb',
#   '00000000-0000-0000-2F29-1A7D5B685C57',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '641f4c07-7c19-4735-bc0d-32b985755628',
#   '2019-06-01T00:00:00',
#   '10:54:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#   'PINEY BRANCH ROAD AT BARRON STREET',
#   '0',
#   '0',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'GMC',
#   'TK',
#   'WHITE',
#   'Warning',
#   '21-201(a1)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'COLUMBIA',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '0.0',
#    '0.0',
#    None,
#    False],
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wqv6_69w7.uhf4',
#   '00000000-0000-0000-C46F-DF2515023C89',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '7dd551dd-58ac-47df-9283-eb1771de6be0',
#   '2019-06-01T00:00:00',
#   '10:11:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#   '321 UNIVERSITY BLVD E',
#   '39.0105033333333',
#   '-77.0011566666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'HONDA',
#   'CIVIC',
#   'BLACK',
#   'Warning',
#   '21-1124.2(d2)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'ADELPHI',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0105033333333',
#    '-77.0011566666667',
#    None,
#    False],
#   '5',
#   '5',
#   '8',
#   '21',
#   '1'],
#  ['row-etfg~us33~rrp6',
#   '00000000-0000-0000-D891-F16EDEBB88F7',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '88cbd867-cf5c-4727-8854-0bbb4ad7c560',
#   '2019-06-01T00:00:00',
#   '10:08:00',
#   'MCP',
#   '5th District, Germantown',
#   'UNSAFE BACKING OF MOTOR VEH.',
#   'PARKING LOT OF 12801 WISTERIA DR',
#   '39.176475',
#   '-77.2688283333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2004',
#   'HONDA',
#   'CRV',
#   'SILVER',
#   'Citation',
#   '21-1102(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.176475',
#    '-77.2688283333333',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '39',
#   '1'],
#  ['row-qtbz-wagp.rnhy',
#   '00000000-0000-0000-4560-458C390798C2',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'd7f432bf-2d04-40a6-aaad-c5f874c52c84',
#   '2019-06-01T00:00:00',
#   '09:42:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER FAILURE TO STOP AT STOP SIGN LINE',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.0614483333333',
#   '-77.1283116666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'HOND',
#   '4S',
#   'BLUE',
#   'Warning',
#   '21-707(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'POTOMAC',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0614483333333',
#    '-77.1283116666667',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-q6sy_ng6f_9sxg',
#   '00000000-0000-0000-DACB-ACC0DF50E017',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'bdde42da-97be-418f-9f80-c4051b125f7c',
#   '2019-06-01T00:00:00',
#   '09:28:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO AVOID COLLISION',
#   'CONNETICUT AVE / JONES BRIDGE RD',
#   '38.9984433333333',
#   '-77.0769466666667',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'DC',
#   '02 - Automobile',
#   '2011',
#   'MINI',
#   'COOPER',
#   'SILVER',
#   'Warning',
#   '21-801(b)',
#   'Transportation Article',
#   'true',
#   'WHITE',
#   'M',
#   'SARASOTA',
#   'FL',
#   'FL',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9984433333333',
#    '-77.0769466666667',
#    None,
#    False],
#   '1',
#   '1',
#   '5',
#   '110',
#   '1'],
#  ['row-jegz.66it-idz5',
#   '00000000-0000-0000-FB1E-99D75B1299E0',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'bdde42da-97be-418f-9f80-c4051b125f7c',
#   '2019-06-01T00:00:00',
#   '09:28:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVER OF MOTOR VEHICLE FOLLOWING VEHICLE CLOSER THAN REASONABLE AND PRUDENT',
#   'CONNETICUT AVE / JONES BRIDGE RD',
#   '38.9984433333333',
#   '-77.0769466666667',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'DC',
#   '02 - Automobile',
#   '2011',
#   'MINI',
#   'COOPER',
#   'SILVER',
#   'Warning',
#   '21-310(a)',
#   'Transportation Article',
#   'true',
#   'WHITE',
#   'M',
#   'SARASOTA',
#   'FL',
#   'FL',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.9984433333333',
#    '-77.0769466666667',
#    None,
#    False],
#   '1',
#   '1',
#   '5',
#   '110',
#   '1'],
#  ['row-irfx_6edp~gdvk',
#   '00000000-0000-0000-9054-C59524819B0A',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '3bc99901-e3dd-4779-8222-bc1a072a07d1',
#   '2019-06-01T00:00:00',
#   '09:27:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#   'OLD GEORGETOWN RD/HUNTINGTON PKWY',
#   '38.995525',
#   '-77.1087783333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'LEXS',
#   'ES350',
#   'SILVER',
#   'Warning',
#   '21-1124.2(d2)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'POTOMAC',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '38.995525',
#    '-77.1087783333333',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-vekd-wk9r~jwdm',
#   '00000000-0000-0000-C858-7240C2485808',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '9f97a802-cb2e-4636-882c-1488bcf1be76',
#   '2019-06-01T00:00:00',
#   '09:26:00',
#   'MCP',
#   '4th District, Wheaton',
#   'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#   'UNIVERSITY BLVD W. / ARCOLA AVE.',
#   '39.0356466666667',
#   '-77.0263816666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2007',
#   'TOYT',
#   'TK',
#   'BLACK',
#   'Warning',
#   '21-1124.2(d2)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'HYATTSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0356466666667',
#    '-77.0263816666667',
#    None,
#    False],
#   '5',
#   '5',
#   '17',
#   '21',
#   '1'],
#  ['row-p2mt~4q2p~m3yd',
#   '00000000-0000-0000-7685-3594C30E20D1',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '377c1501-b29a-4a78-bfb8-4ae5f67d6f18',
#   '2019-06-01T00:00:00',
#   '09:23:00',
#   'MCP',
#   '1st District, Rockville',
#   'FAILURE OF MV OPER TO PRESENT EVIDENCE OF REQUIRED SECURITY ON REQUEST OF A LAW ENFORCEMENT OFFICER',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.061375',
#   '-77.1283383333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'VOLKSWAGON',
#   '4S',
#   'RED',
#   'Warning',
#   '17-104.2(b2)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.061375',
#    '-77.1283383333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-38uu-tkdi-3rb6',
#   '00000000-0000-0000-B0E0-86E4A65A02BC',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '377c1501-b29a-4a78-bfb8-4ae5f67d6f18',
#   '2019-06-01T00:00:00',
#   '09:23:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER FAILURE TO STOP AT STOP SIGN LINE',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.061375',
#   '-77.1283383333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'VOLKSWAGON',
#   '4S',
#   'RED',
#   'Warning',
#   '21-707(a)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.061375',
#    '-77.1283383333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-xsy7~69kd.ncex',
#   '00000000-0000-0000-A666-DF1E9EDF151A',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '377c1501-b29a-4a78-bfb8-4ae5f67d6f18',
#   '2019-06-01T00:00:00',
#   '09:23:00',
#   'MCP',
#   '1st District, Rockville',
#   'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.061375',
#   '-77.1283383333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2013',
#   'VOLKSWAGON',
#   '4S',
#   'RED',
#   'Warning',
#   '13-409(b)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'F',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.061375',
#    '-77.1283383333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-th9d.v64f-wgcm',
#   '00000000-0000-0000-F369-4F9CF6212BD3',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '9151a930-1f1a-4421-90c6-69e347e397b3',
#   '2019-06-01T00:00:00',
#   '09:21:00',
#   'MCP',
#   '5th District, Germantown',
#   'PARKING WHERE PROHIBITED BY OFFICIAL SIGNS',
#   'CRYSTAL ROCK @ CENTURY',
#   '39.18209',
#   '-77.2631766666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2007',
#   'TOYOTA',
#   'TUNDRA',
#   'BLUE, LIGHT',
#   'Citation',
#   '21-1003(aa)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.18209',
#    '-77.2631766666667',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '39',
#   '1'],
#  ['row-eadd_hqc5~kga6',
#   '00000000-0000-0000-12E4-4872B29BBA12',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '2e2ad997-d756-4fb1-b8c7-453b4a2c56c3',
#   '2019-06-01T00:00:00',
#   '09:21:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVING VEH. ON HWY. W/O REQUIRED MINIMUM EQUIPMENT',
#   '355/ HENDERSON CORNER',
#   '39.2020133333333',
#   '-77.2493983333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2010',
#   'TOYOTA',
#   'HIGHLANDER',
#   'SILVER',
#   'Warning',
#   '23-104',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'CLARKSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2020133333333',
#    '-77.2493983333333',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-7qrv.d8ib-ws4z',
#   '00000000-0000-0000-BEAC-9FE48150A196',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '9151a930-1f1a-4421-90c6-69e347e397b3',
#   '2019-06-01T00:00:00',
#   '09:21:00',
#   'MCP',
#   '5th District, Germantown',
#   'OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY',
#   'CRYSTAL ROCK @ CENTURY',
#   '39.18209',
#   '-77.2631766666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2007',
#   'TOYOTA',
#   'TUNDRA',
#   'BLUE, LIGHT',
#   'Warning',
#   '13-401(b1)',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.18209',
#    '-77.2631766666667',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '39',
#   '1'],
#  ['row-phpn.w2i6_2th4',
#   '00000000-0000-0000-ABB6-FF4029430EBD',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ba9185a5-3ea3-4c17-bc2a-ea0c1bfc2cab',
#   '2019-06-01T00:00:00',
#   '09:13:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#   '118 @ CRYSTAL ROCK',
#   '39.1816716666667',
#   '-77.2599833333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2019',
#   'MERCEDES',
#   'GLC300',
#   'BLACK',
#   'Warning',
#   '21-201(a1)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'FREDERICK',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1816716666667',
#    '-77.2599833333333',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '39',
#   '1'],
#  ['row-rf2d-5tt9-ghgx',
#   '00000000-0000-0000-39BD-B1407935780F',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '404d077f-d90c-494a-9558-6891e63ac5ef',
#   '2019-06-01T00:00:00',
#   '09:12:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER FAILURE TO STOP AT STOP SIGN LINE',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.061575',
#   '-77.1284583333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2017',
#   'JEEP',
#   'TK',
#   'BLACK',
#   'Warning',
#   '21-707(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.061575',
#    '-77.1284583333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-57mn.v79u~yxee',
#   '00000000-0000-0000-40DB-35F05D33F4C5',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '2631b755-be0f-4932-8b37-cf629de9c5dd',
#   '2019-06-01T00:00:00',
#   '09:07:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING TO DRIVE MOTOR VEHICLE ON HIGHWAY WITHOUT REQUIRED LICENSE AND AUTHORIZATION',
#   'UNIVERSITY BLVD E / E. FRANKLIN AVE',
#   '39.0130016666667',
#   '-77.00339',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2019',
#   'HYUNDAI',
#   'TUCSON',
#   'GRAY',
#   'Citation',
#   '16-101(a1)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0130016666667',
#    '-77.00339',
#    None,
#    False],
#   '5',
#   '5',
#   '8',
#   '21',
#   '1'],
#  ['row-hdpk.ha3v-tv62',
#   '00000000-0000-0000-4937-7532F48A1488',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '2631b755-be0f-4932-8b37-cf629de9c5dd',
#   '2019-06-01T00:00:00',
#   '09:07:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#   'UNIVERSITY BLVD E / E. FRANKLIN AVE',
#   '39.0130016666667',
#   '-77.00339',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2019',
#   'HYUNDAI',
#   'TUCSON',
#   'GRAY',
#   'Citation',
#   '21-1124.2(d2)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'SILVER SPRING',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0130016666667',
#    '-77.00339',
#    None,
#    False],
#   '5',
#   '5',
#   '8',
#   '21',
#   '1'],
#  ['row-u5h4_6ht2~jvn8',
#   '00000000-0000-0000-D4A7-23D02731DA87',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '270a61b1-4386-4286-84f5-2651f9c9ab0a',
#   '2019-06-01T00:00:00',
#   '09:04:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'MOTOR VEH. MFR. AFTER JUNE 1, 1971, W/O ADEQUATE TAIL LAMPS',
#   'BRIGGS CHANEY RD/OLD COLUMBIA PIKE',
#   '39.08404',
#   '-76.95057',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WV',
#   '02 - Automobile',
#   '2001',
#   'TOYOTA',
#   'AVALON',
#   'GOLD',
#   'Warning',
#   '22-204(a)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'BELTSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.08404',
#    '-76.95057',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-63mn-cs7u_wizj',
#   '00000000-0000-0000-7E63-789A4CB3698B',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '270a61b1-4386-4286-84f5-2651f9c9ab0a',
#   '2019-06-01T00:00:00',
#   '09:04:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS',
#   'BRIGGS CHANEY RD/OLD COLUMBIA PIKE',
#   '39.08404',
#   '-76.95057',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WV',
#   '02 - Automobile',
#   '2001',
#   'TOYOTA',
#   'AVALON',
#   'GOLD',
#   'Citation',
#   '13-411(d)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'BELTSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.08404',
#    '-76.95057',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-b9js_unpe~7zsw',
#   '00000000-0000-0000-64AC-3414A60CBD23',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '270a61b1-4386-4286-84f5-2651f9c9ab0a',
#   '2019-06-01T00:00:00',
#   '09:04:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE',
#   'BRIGGS CHANEY RD/OLD COLUMBIA PIKE',
#   '39.08404',
#   '-76.95057',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WV',
#   '02 - Automobile',
#   '2001',
#   'TOYOTA',
#   'AVALON',
#   'GOLD',
#   'Citation',
#   '13-411(f)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'BELTSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.08404',
#    '-76.95057',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-c7vu.fdnu.57zp',
#   '00000000-0000-0000-D740-A2DA436D45BD',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '270a61b1-4386-4286-84f5-2651f9c9ab0a',
#   '2019-06-01T00:00:00',
#   '09:04:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'UNAUTHORIZED DISPLAY AND USE OF REGISTRATION PLATE',
#   'BRIGGS CHANEY RD/OLD COLUMBIA PIKE',
#   '39.08404',
#   '-76.95057',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WV',
#   '02 - Automobile',
#   '2001',
#   'TOYOTA',
#   'AVALON',
#   'GOLD',
#   'Citation',
#   '13-703(g)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'F',
#   'BELTSVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.08404',
#    '-76.95057',
#    None,
#    False],
#   '5',
#   '5',
#   '53',
#   '12',
#   '1'],
#  ['row-a2g3-6fsz-atup',
#   '00000000-0000-0000-3550-C837191E4F25',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   'ac80eb17-5565-46a2-874e-e7ac6083efce',
#   '2019-06-01T00:00:00',
#   '08:58:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER FAILURE TO STOP AT STOP SIGN LINE',
#   'E JEFFERSON ST AT CONGRESSIONAL LA',
#   '39.06387',
#   '-77.1285183333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2015',
#   'NISS',
#   'SW',
#   'BLUE',
#   'Warning',
#   '21-707(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'ROCKVILLE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.06387',
#    '-77.1285183333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-3iwg_6j7w~uqm5',
#   '00000000-0000-0000-3F6C-0021B6087BCF',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '0309190a-2c26-456f-9160-599863178c05',
#   '2019-06-01T00:00:00',
#   '08:55:00',
#   'MCP',
#   '5th District, Germantown',
#   'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#   'GERMANTOWN ROAD AND MIDDLEBROOK ROAD',
#   '39.1783833333333',
#   '-77.26711',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2010',
#   'NISSAN',
#   'MAXIMA',
#   'BLACK',
#   'Warning',
#   '13-409(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'GERMANTOWN',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1783833333333',
#    '-77.26711',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '39',
#   '1'],
#  ['row-ewi7_92qr~f6m5',
#   '00000000-0000-0000-E925-C1B5A9A09413',
#   0,
#   1559466618,
#   None,
#   1559553012,
#   None,
#   '{ }',
#   '0309190a-2c26-456f-9160-599863178c05',
#   '2019-06-01T00:00:00',
#   '08:55:00',
#   'MCP',
#   '5th District, Germantown',
# ...
#   '00000000-0000-0000-E7EA-57FE7C5E3650',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'e2a6d6e3-6119-47f7-a736-22ef12a9cc0e',
#   '2019-05-30T00:00:00',
#   '11:50:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'EXCEEDING POSTED MAXIMUM SPEED LIMIT: 54 MPH IN A POSTED 45 MPH ZONE',
#   'SHADY GROVE RD & MID-CTY HWY',
#   '39.1446333333333',
#   '-77.1485066666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2008',
#   'FORD',
#   'TK',
#   'BLACK',
#   'Citation',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'HISPANIC',
#   'F',
#   'DERWOOD',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1446333333333',
#    '-77.1485066666667',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '51',
#   '1'],
#  ['row-wu84-qmwa.aw4r',
#   '00000000-0000-0000-9BE5-4270ADFA7F9C',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '1b8b2ae9-46a2-4359-981e-cb86e7b343a1',
#   '2019-05-30T00:00:00',
#   '11:44:00',
#   'MCP',
#   '1st District, Rockville',
#   'FAILURE OF MV OPER TO PRESENT EVIDENCE OF REQUIRED SECURITY ON REQUEST OF A LAW ENFORCEMENT OFFICER',
#   'N WASHINGTON ST@BEALL AVE',
#   '39.0875416666667',
#   '-77.1536266666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2015',
#   'VOLKSWAGON',
#   'GOLF',
#   'BLUE',
#   'Warning',
#   '17-104.2(b2)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'FREMONT',
#   'CA',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0875416666667',
#    '-77.1536266666667',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '71',
#   '12'],
#  ['row-a7tx~gwxs-x4xa',
#   '00000000-0000-0000-6253-4CFF6ABE0510',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '1b8b2ae9-46a2-4359-981e-cb86e7b343a1',
#   '2019-05-30T00:00:00',
#   '11:44:00',
#   'MCP',
#   '1st District, Rockville',
#   'DRIVER CHANGING LANES WHEN UNSAFE',
#   'N WASHINGTON ST@BEALL AVE',
#   '39.0875416666667',
#   '-77.1536266666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2015',
#   'VOLKSWAGON',
#   'GOLF',
#   'BLUE',
#   'Warning',
#   '21-309(b)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'FREMONT',
#   'CA',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0875416666667',
#    '-77.1536266666667',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '71',
#   '12'],
#  ['row-7ipq~2etu~yrwr',
#   '00000000-0000-0000-8834-8AB8CB0A87A7',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '1b8b2ae9-46a2-4359-981e-cb86e7b343a1',
#   '2019-05-30T00:00:00',
#   '11:44:00',
#   'MCP',
#   '1st District, Rockville',
#   'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#   'N WASHINGTON ST@BEALL AVE',
#   '39.0875416666667',
#   '-77.1536266666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2015',
#   'VOLKSWAGON',
#   'GOLF',
#   'BLUE',
#   'Warning',
#   '13-409(b)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'FREMONT',
#   'CA',
#   'CA',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0875416666667',
#    '-77.1536266666667',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '71',
#   '12'],
#  ['row-jii7_88aw-g4fe',
#   '00000000-0000-0000-2244-225188B22D1D',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '5d14425b-b66b-4b89-aa2e-b7b723744f69',
#   '2019-05-30T00:00:00',
#   '11:41:00',
#   'MCP',
#   '5th District, Germantown',
#   'EXCEEDING POSTED SPEED LIMIT IN SCHOOL ZONE WITH NOTICE OF DOUBLE FINES: 52 MPH IN 30 ZONE',
#   '18001 BARNSVILLE RD',
#   '39.2237255',
#   '-77.3916248333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2002',
#   'CHEV',
#   'TK',
#   'WHITE',
#   'Citation',
#   '21-803.1(e)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GERMANTOWN',
#   'MD',
#   'MD',
#   'I - Marked Moving Radar (Moving)',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2237255',
#    '-77.3916248333333',
#    None,
#    False],
#   '2',
#   '2',
#   '41',
#   '78',
#   '1'],
#  ['row-hrnr_d4zc-npqh',
#   '00000000-0000-0000-24D3-A86FE440D677',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '5d14425b-b66b-4b89-aa2e-b7b723744f69',
#   '2019-05-30T00:00:00',
#   '11:41:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVER  WRITING,SENDING,READING A TEXT,ELECTRONIC MSG. WHILE OPER. VEH. IN TRAVEL PORTION OF HWY',
#   '18001 BARNSVILLE RD',
#   '39.2237255',
#   '-77.3916248333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2002',
#   'CHEV',
#   'TK',
#   'WHITE',
#   'Citation',
#   '21-1124.1(b)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GERMANTOWN',
#   'MD',
#   'MD',
#   'I - Marked Moving Radar (Moving)',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2237255',
#    '-77.3916248333333',
#    None,
#    False],
#   '2',
#   '2',
#   '41',
#   '78',
#   '1'],
#  ['row-d9ki~d5xw-nqqc',
#   '00000000-0000-0000-E90D-64D723721508',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '5d14425b-b66b-4b89-aa2e-b7b723744f69',
#   '2019-05-30T00:00:00',
#   '11:41:00',
#   'MCP',
#   '5th District, Germantown',
#   'NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON',
#   '18001 BARNSVILLE RD',
#   '39.2237255',
#   '-77.3916248333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2002',
#   'CHEV',
#   'TK',
#   'WHITE',
#   'Citation',
#   '21-901.1(b)',
#   'Transportation Article',
#   'false',
#   'BLACK',
#   'M',
#   'GERMANTOWN',
#   'MD',
#   'MD',
#   'I - Marked Moving Radar (Moving)',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2237255',
#    '-77.3916248333333',
#    None,
#    False],
#   '2',
#   '2',
#   '41',
#   '78',
#   '1'],
#  ['row-ae3r_fjfy-dtis',
#   '00000000-0000-0000-E5C8-32C723FF8904',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '73c6c677-cf44-45d3-be25-9823bac8731b',
#   '2019-05-30T00:00:00',
#   '11:37:00',
#   'MCP',
#   '6th District, Gaithersburg / Montgomery Village',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH',
#   'SHADY GROVE RD & MID-CTY HWY',
#   '39.143675',
#   '-77.1505066666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2016',
#   'CHEV',
#   'TK',
#   'BLACK',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'JESSUP',
#   'MD',
#   'MD',
#   'Q - Marked Laser',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.143675',
#    '-77.1505066666667',
#    None,
#    False],
#   '3',
#   '3',
#   '36',
#   '51',
#   '1'],
#  ['row-szkr-uitn~zmjr',
#   '00000000-0000-0000-FAD5-B1808A9FF844',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'd9b53d2b-1ca0-462c-a90d-35813c93ffa7',
#   '2019-05-30T00:00:00',
#   '11:26:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#   '18506 BARNESVILLE RD',
#   '39.2219176666667',
#   '-77.3861316666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2002',
#   'INTL',
#   'DS',
#   'WHITE',
#   'Citation',
#   '21-1124.2(d2)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'THURMONT',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2219176666667',
#    '-77.3861316666667',
#    None,
#    False],
#   '2',
#   '2',
#   '41',
#   '78',
#   '2'],
#  ['row-nevy-tzwp_7wbx',
#   '00000000-0000-0000-25C9-C64D6AA3F5F9',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '347bc5a4-cc69-4770-b326-46fcb742da2d',
#   '2019-05-30T00:00:00',
#   '11:20:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVING ON LEFT SIDE OF ROADWAY IN POSTED NO PASSING ZONE MARKED BY PAVEMENT STRIPING',
#   'WOODFIELD RD/ROCKY RD',
#   '39.2323383333333',
#   '-77.1789366666667',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2004',
#   'TOYT',
#   '4S',
#   'SILVER',
#   'Warning',
#   '21-307(c)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'GAITHERSBURG',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.2323383333333',
#    '-77.1789366666667',
#    None,
#    False],
#   '2',
#   '2',
#   '46',
#   '29',
#   '1'],
#  ['row-i2sr-ndiu~nh8v',
#   '00000000-0000-0000-D520-A21C9E47E764',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'f5c29cad-810d-4804-a400-5a3f48ac5086',
#   '2019-05-30T00:00:00',
#   '11:04:00',
#   'MCP',
#   '3rd District, Silver Spring',
#   'DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY 45',
#   'UNIV BLVD W / LORAIN AVE',
#   '0',
#   '0',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2012',
#   'GMC',
#   'TK',
#   'BLACK',
#   'Citation',
#   '21-801(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'M',
#   'DENTON',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '0.0',
#    '0.0',
#    None,
#    False],
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-x3gc-a3sp~z4pc',
#   '00000000-0000-0000-809C-D3A20D961F8D',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'b9666049-72f7-4337-a7f9-1daf7bce770d',
#   '2019-05-30T00:00:00',
#   '10:55:00',
#   'MCP',
#   '2nd District, Bethesda',
#   'DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS',
#   'DEMOCRACY BLVD/FERNWOOD RD',
#   '39.0216616666667',
#   '-77.13645',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2009',
#   'BMW',
#   '4DR',
#   'BLACK',
#   'Citation',
#   '13-411(d)',
#   'Transportation Article',
#   'false',
#   'ASIAN',
#   'M',
#   'GERMANTOWN',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0216616666667',
#    '-77.13645',
#    None,
#    False],
#   '1',
#   '1',
#   '12',
#   '103',
#   '1'],
#  ['row-dfzm~qy4e~u997',
#   '00000000-0000-0000-4432-7EB7553890B9',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'b0b122e5-c316-4b83-9f7b-6080833f81e5',
#   '2019-05-30T00:00:00',
#   '10:54:00',
#   'MCP',
#   '1st District, Rockville',
#   'PARKING WHERE PROHIBITED BY OFFICIAL SIGNS',
#   '800 BLK ROCKVILLE PIKE',
#   '39.0746566666667',
#   '-77.1382633333333',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '02 - Automobile',
#   '2018',
#   'MERZ',
#   '4H',
#   'SILVER',
#   'Warning',
#   '21-1003(aa)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'POTOMAC',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0746566666667',
#    '-77.1382633333333',
#    None,
#    False],
#   '3',
#   '3',
#   '25',
#   '60',
#   '12'],
#  ['row-3weq_embf.zzzb',
#   '00000000-0000-0000-9A8F-CE9C0728BB30',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'ca3a714d-92c7-4e1a-80b0-34f5bcbade2b',
#   '2019-05-30T00:00:00',
#   '10:43:00',
#   'MCP',
#   '5th District, Germantown',
#   'EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH',
#   'GERMANTOWN ROAD/ OBSERVATION DRIVE',
#   '39.1905983333333',
#   '-77.24812',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WI',
#   '02 - Automobile',
#   '2018',
#   'GMC',
#   'UT',
#   'SILVER',
#   'Warning',
#   '21-801.1',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GLENDALE',
#   'WI',
#   'WI',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1905983333333',
#    '-77.24812',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-yift~mb7u.8s2v',
#   '00000000-0000-0000-71AB-819637450664',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'ca3a714d-92c7-4e1a-80b0-34f5bcbade2b',
#   '2019-05-30T00:00:00',
#   '10:43:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVER CHANGING LANES WHEN UNSAFE',
#   'GERMANTOWN ROAD/ OBSERVATION DRIVE',
#   '39.1905983333333',
#   '-77.24812',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WI',
#   '02 - Automobile',
#   '2018',
#   'GMC',
#   'UT',
#   'SILVER',
#   'Warning',
#   '21-309(b)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GLENDALE',
#   'WI',
#   'WI',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1905983333333',
#    '-77.24812',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-sckq-8nmh-c7mb',
#   '00000000-0000-0000-799B-1233EC8638A7',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'ca3a714d-92c7-4e1a-80b0-34f5bcbade2b',
#   '2019-05-30T00:00:00',
#   '10:43:00',
#   'MCP',
#   '5th District, Germantown',
#   'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#   'GERMANTOWN ROAD/ OBSERVATION DRIVE',
#   '39.1905983333333',
#   '-77.24812',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WI',
#   '02 - Automobile',
#   '2018',
#   'GMC',
#   'UT',
#   'SILVER',
#   'Warning',
#   '21-201(a1)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GLENDALE',
#   'WI',
#   'WI',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1905983333333',
#    '-77.24812',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-suy7-hnip~8z3f',
#   '00000000-0000-0000-A715-3D9C2607E95B',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'ca3a714d-92c7-4e1a-80b0-34f5bcbade2b',
#   '2019-05-30T00:00:00',
#   '10:43:00',
#   'MCP',
#   '5th District, Germantown',
#   'STOPPING VEH. IN INTERSECTION',
#   'GERMANTOWN ROAD/ OBSERVATION DRIVE',
#   '39.1905983333333',
#   '-77.24812',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WI',
#   '02 - Automobile',
#   '2018',
#   'GMC',
#   'UT',
#   'SILVER',
#   'Warning',
#   '21-1003(d)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GLENDALE',
#   'WI',
#   'WI',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1905983333333',
#    '-77.24812',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-dq2e-z5qr_c39c',
#   '00000000-0000-0000-1E64-66DDDDE8C900',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   'ca3a714d-92c7-4e1a-80b0-34f5bcbade2b',
#   '2019-05-30T00:00:00',
#   '10:43:00',
#   'MCP',
#   '5th District, Germantown',
#   'FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADWAY WHEN REQUIRED',
#   'GERMANTOWN ROAD/ OBSERVATION DRIVE',
#   '39.1905983333333',
#   '-77.24812',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'WI',
#   '02 - Automobile',
#   '2018',
#   'GMC',
#   'UT',
#   'SILVER',
#   'Warning',
#   '21-301(a)',
#   'Transportation Article',
#   'false',
#   'WHITE',
#   'F',
#   'GLENDALE',
#   'WI',
#   'WI',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.1905983333333',
#    '-77.24812',
#    None,
#    False],
#   '2',
#   '2',
#   '39',
#   '36',
#   '1'],
#  ['row-k8y8.2z2e_4kj8',
#   '00000000-0000-0000-3113-7A3A5827E712',
#   0,
#   1559293819,
#   None,
#   1559466618,
#   None,
#   '{ }',
#   '7ca6b1eb-cd7c-442f-83ad-33b0e7e92023',
#   '2019-05-30T00:00:00',
#   '10:42:00',
#   'MCP',
#   '4th District, Wheaton',
#   'HEADLIGHT, TAILLIGHT, STOPLIGHT, TURN SIGNAL, ID LIGHT, CLEARANCE LIGHT, MARKER LIGHT INOPERATIVE',
#   'UNIVERSITY BLV W / AMHERST AVE',
#   '39.0388133333333',
#   '-77.035675',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'MD',
#   '05 - Light Duty Truck',
#   '2014',
#   'MITS',
#   'TK',
#   'WHITE',
#   'Warning',
#   '11-393.9',
#   'Maryland Rules',
#   'false',
#   'BLACK',
#   'M',
#   'BALTIMORE',
#   'MD',
#   'MD',
#   'A - Marked Patrol',
#   ['{"address": "", "city": "", "state": "", "zip": ""}',
#    '39.0388133333333',
#    '-77.035675',
#    None,
#    False],
#   '4',
#   '4',
#   '16',
#   '17',
#   '1'],
#  ...]

# %%
#No. of traffic violations
len(data['data'])
# Out:
# 1528078

# %%
#Test navigation: Get date of first violation
data['data'][1][9]
# Out:
# '2019-06-01T00:00:00'

# %%
#Set violations list to a variable
violations = data['data']

# %%
type(violations)
# Out:
# list

# %%
#initialize variables for empty lists to hold data
#
DateofStopls = []
TimeofStopls = []
Agencyls = []
Subagencyls = []
Descriptionls = []
Locationls = []
Latitudels = []
Longitudels = []
VehicleTypels = []
VehicleYearls = []
VehicleMakels = []
VehicleModells = []
VehicleColorls = []
ViolationTypels = []
Racels = []
Genderls = []
DriverStatels = []
DriverLicenseStatels = []
ArrestTypels = []

# %%
#Print a sample violation to verify data
print(violations[9])
# Out:
# ['row-p96m_sum7.bag5', '00000000-0000-0000-7505-3095F3ED0FBA', 0, 1559466618, None, 1559553012, None, '{ }', 'fddf7f5d-6dd7-4e0c-9950-1e73b61e9202', '2019-06-01T00:00:00', '13:06:00', 'MCP', '3rd District, Silver Spring', 'STOPPING, PARKING, LEAVING STANDING VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT', '8512 FENTON ST.', '38.9961883333333', '-77.0248416666667', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'MD', '02 - Automobile', '2013', 'TOYOTA', 'COROLLA', 'GOLD', 'Citation', '21-1001(a)', 'Transportation Article', 'false', 'BLACK', 'M', 'SILVER SPRING', 'MD', 'MD', 'A - Marked Patrol', ['{"address": "", "city": "", "state": "", "zip": ""}', '38.9961883333333', '-77.0248416666667', None, False], '5', '5', '7', '3065', '1']

# %%
#Fill lists with data

for violation in violations:  #data[index]
    
    DateofStopls.append(violation[9])
    TimeofStopls.append(violation[10])
    Agencyls.append(violation[11])
    Subagencyls.append(violation[12])
    Descriptionls.append(violation[13])
    Locationls.append(violation[14])
    Latitudels.append(violation[15])
    Longitudels.append(violation[16])
    VehicleTypels.append(violation[28])
    VehicleYearls.append(violation[29])
    VehicleMakels.append(violation[30])
    VehicleModells.append(violation[31])
    VehicleColorls.append(violation[32])
    ViolationTypels.append(violation[33])
    Racels.append(violation[37])
    Genderls.append(violation[38])
    DriverStatels.append(violation[40])
    DriverLicenseStatels.append(violation[41])
    ArrestTypels.append(violation[42])

# %%
#verify amount of informaton in date list
len(DateofStopls)
# Out:
# 1528078

# %%
#see first 20 values within Description list
Descriptionls[:20]
# Out:
# ['DRIVER CHANGING LANES WHEN UNSAFE',
#  'DRIVER FAILURE TO YIELD RIGHT-OF-WAY TO VEH. UPON EMERGING FROM DRIVEWAY',
#  'FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO AVOID COLLISION',
#  'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#  'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#  'DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103',
#  'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE',
#  'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH',
#  'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#  'STOPPING, PARKING, LEAVING STANDING VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT',
#  'DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY',
#  'DRIVER FAIL TO STOP AT STEADY RED ARROW SIGNAL',
#  'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#  'FAILURE NOTIFY ADM. ADDRESS CHANGE',
#  'UNAUTHORIZED DISPLAY AND USE OF REGISTRATION PLATE',
#  'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE',
#  'DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS',
#  'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#  'EXCEEDING POSTED MAXIMUM SPEED LIMIT: 54 MPH IN A POSTED 35 MPH ZONE',
#  'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION']

# %%
#check that values for each list add up to be the same

print(len(DateofStopls))
print(len(TimeofStopls))
print(len(Agencyls))
print(len(Subagencyls))
print(len(Descriptionls))
print(len(Locationls))
print(len(Latitudels))
print(len(Longitudels))
print(len(VehicleTypels))
print(len(VehicleYearls))
print(len(VehicleMakels))         
print(len(VehicleModells))
print(len(VehicleColorls))
print(len(ViolationTypels))
print(len(Racels))
print(len(Genderls))
print(len(DriverStatels))
print(len(DriverLicenseStatels))
print(len(ArrestTypels))
# Out:
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078
# 1528078

# %% [markdown]
# #### Make gathered information into dataframe

# %%
#zip lists together into one list
#will put in order instructor wants columns to be
ViolationsList = list(zip(DateofStopls, TimeofStopls, Agencyls, Subagencyls, Descriptionls, Locationls, Latitudels, Longitudels, VehicleTypels, VehicleYearls, VehicleMakels, VehicleModells, VehicleColorls, ViolationTypels, Racels, Genderls, DriverStatels, DriverLicenseStatels, ArrestTypels))
       
#make list of column names
names = ['DateofStop', 'TimeofStop', 'Agency', 'Subagency', 'Description', 'Location', 'Latitude', 'Longitude', 'VehicleType', 'VehicleYear', 'VehicleMake', 'VehicleModel', 'VehicleColor', 'ViolationType', 'Race', 'Gender', 'DriverState', 'DriverLicenseState', 'ArrestType']

# %%
#make the dataframe
df = pd.DataFrame(ViolationsList, columns=names)

df.head()
# Out:
#             DateofStop TimeofStop Agency                    Subagency  \
# 0  2019-06-01T00:00:00   13:38:00    MCP       2nd District, Bethesda
# 1  2019-06-01T00:00:00   13:38:00    MCP       2nd District, Bethesda
# 2  2019-06-01T00:00:00   13:38:00    MCP       2nd District, Bethesda
# 3  2019-06-01T00:00:00   13:23:00    MCP  3rd District, Silver Spring
# 4  2019-06-01T00:00:00   13:23:00    MCP       2nd District, Bethesda
#
#                                          Description  \
# 0                  DRIVER CHANGING LANES WHEN UNSAFE
# 1  DRIVER FAILURE TO YIELD RIGHT-OF-WAY TO VEH. U...
# 2  FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO...
# 3  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 4         EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH
#
#                       Location          Latitude          Longitude  \
# 0  RANDOLPH RD / NEW HAMPSHIRE          39.07592  -77.0011316666667
# 1  RANDOLPH RD / NEW HAMPSHIRE          39.07592  -77.0011316666667
# 2  RANDOLPH RD / NEW HAMPSHIRE          39.07592  -77.0011316666667
# 3  COLUMBIA PIKE / OAK LEAF DR  39.0407683333333  -76.9959166666667
# 4        RIVER RD/BRAEBRN PKWY         38.978335          -77.13062
#
#        VehicleType VehicleYear VehicleMake VehicleModel VehicleColor  \
# 0  02 - Automobile        2014        HYUN           TK       SILVER
# 1  02 - Automobile        2014        HYUN           TK       SILVER
# 2  02 - Automobile        2014        HYUN           TK       SILVER
# 3  02 - Automobile        2008       MAZDA           4D  BLUE, LIGHT
# 4  02 - Automobile        2014        HOND           4D       BRONZE
#
#   ViolationType      Race Gender DriverState DriverLicenseState  \
# 0       Warning     WHITE      F          MD                 MD
# 1       Warning     WHITE      F          MD                 MD
# 2       Warning     WHITE      F          MD                 MD
# 3      Citation  HISPANIC      M          MD                 MD
# 4       Warning  HISPANIC      F          MD                 MD
#
#                     ArrestType
# 0            A - Marked Patrol
# 1            A - Marked Patrol
# 2            A - Marked Patrol
# 3            A - Marked Patrol
# 4  E - Marked Stationary Radar
